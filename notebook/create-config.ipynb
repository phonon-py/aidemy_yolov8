# %% [markdown]
# **2.1.1 物体検出モデル作成の準備**

# %% [markdown]
# YOLOv8のgitリポジトリをクローンする

# %%
# YOLOv8のリポジトリをGitHubからマイドライブにクローンする。一度クローンしたらコメントアウトする

# git clone https://github.com/ultralytics/ultralytics.git

# %% [markdown]
# configファイルの作成

# %%
# yamlファイルの中身
yaml_content = r"""
path: 'C:\Users\041674\VSCode\YOLOv8\datasets'  # dataset root dir
train: images/train
val: images/val

# Classes
names:
  0: raccoon
  1: cat
"""

# %%
import io

# yamlファイルの保存
yaml_file = io.StringIO(yaml_content)
with open(r'C:\Users\041674\VSCode\YOLOv8\ultralytics\ultralytics\cfg\datasets\raccoon-cat.yaml', 'w') as f:
    f.write(yaml_file.getvalue())

# %%
# datasetsディレクトリにraccoon-cat.yamlが存在するか確認
import os

os.listdir(r'C:\Users\041674\VSCode\YOLOv8\ultralytics\ultralytics\cfg\datasets')
# Out:
# ['african-wildlife.yaml',
#  'Argoverse.yaml',
#  'brain-tumor.yaml',
#  'carparts-seg.yaml',
#  'coco-pose.yaml',
#  'coco.yaml',
#  'coco128-seg.yaml',
#  'coco128.yaml',
#  'coco8-pose.yaml',
#  'coco8-seg.yaml',
#  'coco8.yaml',
#  'crack-seg.yaml',
#  'dota8.yaml',
#  'DOTAv1.5.yaml',
#  'DOTAv1.yaml',
#  'GlobalWheat2020.yaml',
#  'ImageNet.yaml',
#  'lvis.yaml',
#  'Objects365.yaml',
#  'open-images-v7.yaml',
#  'package-seg.yaml',
#  'raccoon-cat.yaml',
#  'signature.yaml',
#  'SKU-110K.yaml',
#  'tiger-pose.yaml',
#  'VisDrone.yaml',
#  'VOC.yaml',
#  'xView.yaml']
